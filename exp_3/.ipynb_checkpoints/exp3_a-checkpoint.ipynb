# %%
# !pip install simpletransformers
# !pip install torch
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: simpletransformers in c:\users\gokha\anaconda3\lib\site-packages (0.61.6)
# Requirement already satisfied: regex in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (2020.10.15)
# Requirement already satisfied: pandas in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (1.1.3)
# Requirement already satisfied: scikit-learn in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (0.23.2)
# Requirement already satisfied: streamlit in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (0.82.0)
# Requirement already satisfied: sentencepiece in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (0.1.95)
# Requirement already satisfied: scipy in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (1.5.2)
# Requirement already satisfied: datasets in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (1.7.0)
# Requirement already satisfied: transformers>=4.2.0 in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (4.6.1)
# Requirement already satisfied: numpy in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (1.19.2)
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (4.50.2)
# Requirement already satisfied: seqeval in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tokenizers in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (0.10.3)
# Requirement already satisfied: wandb in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (0.10.31)
# Requirement already satisfied: requests in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (2.24.0)
# Requirement already satisfied: tensorboardx in c:\users\gokha\anaconda3\lib\site-packages (from simpletransformers) (2.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\gokha\anaconda3\lib\site-packages (from pandas->simpletransformers) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\gokha\anaconda3\lib\site-packages (from pandas->simpletransformers) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\gokha\anaconda3\lib\site-packages (from scikit-learn->simpletransformers) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from scikit-learn->simpletransformers) (2.1.0)
# Requirement already satisfied: blinker in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (1.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (8.0.1)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (0.10.3)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (3.17.2)
# Requirement already satisfied: validators in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (0.18.2)
# Requirement already satisfied: packaging in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (20.4)
# Requirement already satisfied: pyarrow; python_version < "3.9" in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: tzlocal in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: toml in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (0.10.1)
# Requirement already satisfied: base58 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (2.1.0)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: altair>=3.2.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (6.0.4)
# Requirement already satisfied: gitpython in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (3.1.17)
# Requirement already satisfied: astor in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (0.8.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\gokha\anaconda3\lib\site-packages (from streamlit->simpletransformers) (0.6.2)
# Requirement already satisfied: xxhash in c:\users\gokha\anaconda3\lib\site-packages (from datasets->simpletransformers) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\gokha\anaconda3\lib\site-packages (from datasets->simpletransformers) (0.70.11.1)
# Requirement already satisfied: dill in c:\users\gokha\anaconda3\lib\site-packages (from datasets->simpletransformers) (0.3.3)
# Requirement already satisfied: huggingface-hub<0.1.0 in c:\users\gokha\anaconda3\lib\site-packages (from datasets->simpletransformers) (0.0.8)
# Requirement already satisfied: fsspec in c:\users\gokha\anaconda3\lib\site-packages (from datasets->simpletransformers) (0.8.3)
# Requirement already satisfied: sacremoses in c:\users\gokha\anaconda3\lib\site-packages (from transformers>=4.2.0->simpletransformers) (0.0.45)
# Requirement already satisfied: filelock in c:\users\gokha\anaconda3\lib\site-packages (from transformers>=4.2.0->simpletransformers) (3.0.12)
# Requirement already satisfied: six>=1.13.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (1.16.0)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (5.7.2)
# Requirement already satisfied: sentry-sdk>=0.4.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (1.1.0)
# Requirement already satisfied: PyYAML in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (5.3.1)
# Requirement already satisfied: pathtools in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (0.4.0)
# Requirement already satisfied: configparser>=3.8.1 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (5.0.2)
# Requirement already satisfied: subprocess32>=3.5.3 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (3.5.4)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\gokha\anaconda3\lib\site-packages (from wandb->simpletransformers) (1.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gokha\anaconda3\lib\site-packages (from requests->simpletransformers) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gokha\anaconda3\lib\site-packages (from requests->simpletransformers) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gokha\anaconda3\lib\site-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gokha\anaconda3\lib\site-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\gokha\anaconda3\lib\site-packages (from validators->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gokha\anaconda3\lib\site-packages (from packaging->streamlit->simpletransformers) (2.4.7)
# Requirement already satisfied: jsonschema in c:\users\gokha\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (3.2.0)
# Requirement already satisfied: entrypoints in c:\users\gokha\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.3)
# Requirement already satisfied: jinja2 in c:\users\gokha\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.2)
# Requirement already satisfied: toolz in c:\users\gokha\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\gokha\anaconda3\lib\site-packages (from gitpython->streamlit->simpletransformers) (4.0.7)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\gokha\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.5.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in c:\users\gokha\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\gokha\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit->simpletransformers) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\gokha\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit->simpletransformers) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\gokha\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit->simpletransformers) (20.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gokha\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (1.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\gokha\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit->simpletransformers) (4.0.0)
# Requirement already satisfied: ipython-genutils in c:\users\gokha\anaconda3\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\gokha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (7.19.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\gokha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\gokha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.5.1)
# Requirement already satisfied: jupyter-client in c:\users\gokha\anaconda3\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (6.1.7)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.0.8)
# Requirement already satisfied: backcall in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.17.1)
# Requirement already satisfied: pygments in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.7.2)
# Requirement already satisfied: pickleshare in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\gokha\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.4.4)
# Requirement already satisfied: jupyter-core in c:\users\gokha\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\gokha\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (6.1.4)
# Requirement already satisfied: pyzmq>=13 in c:\users\gokha\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (19.0.2)
# Requirement already satisfied: wcwidth in c:\users\gokha\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\gokha\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\gokha\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (227)
# Requirement already satisfied: Send2Trash in c:\users\gokha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\gokha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gokha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.9.1)
# Requirement already satisfied: nbconvert in c:\users\gokha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\gokha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\gokha\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.7)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.4.3)
# Requirement already satisfied: testpath in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.4.4)
# Requirement already satisfied: bleach in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.2.1)
# Requirement already satisfied: defusedxml in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gokha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.14.3)
# Requirement already satisfied: webencodings in c:\users\gokha\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Requirement already satisfied: async-generator in c:\users\gokha\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\gokha\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.4.2)
# Requirement already satisfied: pycparser in c:\users\gokha\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.20)
# Requirement already satisfied: torch in c:\users\gokha\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: typing-extensions in c:\users\gokha\anaconda3\lib\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in c:\users\gokha\anaconda3\lib\site-packages (from torch) (1.19.2)
# Collecting sentence_transformers
#   Downloading sentence-transformers-1.2.0.tar.gz (81 kB)
# Requirement already satisfied: transformers<5.0.0,>=3.1.0 in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (4.6.1)
# Requirement already satisfied: tqdm in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (4.50.2)
# Requirement already satisfied: torch>=1.6.0 in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (1.8.1)
# Collecting torchvision
#   Downloading torchvision-0.9.1-cp38-cp38-win_amd64.whl (852 kB)
# Requirement already satisfied: numpy in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (1.19.2)
# Requirement already satisfied: scikit-learn in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (0.23.2)
# Requirement already satisfied: scipy in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: nltk in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (3.5)
# Requirement already satisfied: sentencepiece in c:\users\gokha\anaconda3\lib\site-packages (from sentence_transformers) (0.1.95)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub==0.0.8 in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.0.8)
# Requirement already satisfied: packaging in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (20.4)
# Requirement already satisfied: requests in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2.24.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (2020.10.15)
# Requirement already satisfied: filelock in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: sacremoses in c:\users\gokha\anaconda3\lib\site-packages (from transformers<5.0.0,>=3.1.0->sentence_transformers) (0.0.45)
# Requirement already satisfied: typing-extensions in c:\users\gokha\anaconda3\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\gokha\anaconda3\lib\site-packages (from torchvision->sentence_transformers) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gokha\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\gokha\anaconda3\lib\site-packages (from scikit-learn->sentence_transformers) (0.17.0)
# Requirement already satisfied: click in c:\users\gokha\anaconda3\lib\site-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: six in c:\users\gokha\anaconda3\lib\site-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence_transformers) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gokha\anaconda3\lib\site-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gokha\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gokha\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gokha\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gokha\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=3.1.0->sentence_transformers) (1.25.11)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.2.0-py3-none-any.whl size=123343 sha256=8d541e756430550c272a9386c6c89610400ed32945539c34e4d0712970523dd8
#   Stored in directory: c:\users\gokha\appdata\local\pip\cache\wheels\b4\6e\a8\cf238561a31fae695f652b56c429cf926c9cd969fad14b3685
# Successfully built sentence-transformers
# Installing collected packages: torchvision, sentence-transformers
# Successfully installed sentence-transformers-1.2.0 torchvision-0.9.1

# %%
# Gokhan Has - Experiment 03 - A
import os
import ast
import pandas as pd
import numpy as np
import statistics

from simpletransformers.ner import NERModel
from operator import itemgetter
from scipy import spatial
from itertools import chain
from sentence_transformers import SentenceTransformer

# %%
def read_csv(filepath):
    if os.path.splitext(filepath)[1] != '.csv':
        return  # or whatever
    seps = [';', '\t']  # ',' is default
    encodings = [None, 'utf-8', 'ISO-8859-1', 'utf-16', 'ascii']  # None is default
    for sep in seps:
        for encoding in encodings:
            try:
                return pd.read_csv(filepath, encoding=encoding, sep=sep)
            except Exception:  # should really be more specific
                pass
    raise ValueError("{!r} is has no encoding in {} or seperator in {}"
                     .format(filepath, encodings, seps))

# %%
# Install NER model
model_NER = NERModel('bert', '../ner_model/', use_cuda=False)

# %%
# Read the dataset and initialize dataset values ...
df = read_csv('../datasets/exp2_dataset.csv')

all_sentences = []
oldVal = 0
newVal = 1
for index in range(0, len(df)):
    newVal = df['SENTENCE_ID'][index]
    if not oldVal == newVal:
        all_sentences.append( {'index': df['SENTENCE_ID'][index], 'sentence': df['SENTENCE'][index]})
        oldVal = newVal

# %%
# Get the query sentence
query_sentence = "insan öldürmenin cezası nedir"

# Get the query sentence list
query_sentence_list = query_sentence.split(' ')

# Get the query sentence named entities
prediction, model_output = model_NER.predict([query_sentence])
prediction = prediction[0]

print(prediction)

o_element_list = []
ner_query_list = []
for index, tup in enumerate(prediction):
    if not tup[query_sentence_list[index]] == 'O':
        ner_query_list.append(tup)
    else:
        o_element_list.append(query_sentence_list[index])
        
prediction = ner_query_list
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Running Prediction'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# [{'insan': 'B-ELEMENT_OF_CRIME'}, {'öldürmenin': 'I-ELEMENT_OF_CRIME'}, {'cezası': 'I-PUNISHMENT'}, {'nedir': 'O'}]

# %%
# Get the query sentence's word's embedding by using ../ner_model. 
query_word_embeddings_list = []

words = []
new_sentences = []
print(query_sentence_list)
for query_index, query_word in enumerate(query_sentence_list):
    if not query_word in o_element_list:
        print(query_word)
        query_word_embeddings = model_output[0][query_index][query_word][0]
        query_word_embeddings_list.append(query_word_embeddings)
# Out:
# ['insan', 'öldürmenin', 'cezası', 'nedir']
# insan
# öldürmenin
# cezası

# %%
# In this cell, compare dataset's named entity's embeddings and query sentence's word's embeddings...

for i in range(0, len(o_element_list)):
    query_sentence_list.remove(o_element_list[i])


results_list = []

oldIndex = 1
newIndex = 1
for k in range(0, len(prediction)):
    control_tag = prediction[k][query_sentence_list[k]]
    result_list = []
    cumle_list = []
    dataset_tag = ""
    for index in range(0, len(df)):
        newIndex = df['SENTENCE_ID'][index] 
        if not (newIndex == oldIndex):
            if len(cumle_list) == 0:
                result_list.append({'sentence_id' : oldIndex, 'distance': 0.0})
            else:
                avg = statistics.mean(cumle_list)
                result_list.append({'sentence_id' : oldIndex, 'distance': avg})
            # result_list.append(cumle_list)
            cumle_list = []
            oldIndex = newIndex
            
        dataset_tag = (df['TAG'][index])[2:len(df['TAG'][index])]
        # print(newIndex, df['WORD'][index], dataset_tag)
        if dataset_tag == control_tag[2:len(control_tag)]:
            # convert list string to list
            veriset_emb = ast.literal_eval(df['EMBEDDING'][index])
            # find cosine distance between query word and dataset word tag
            distances = 1 - spatial.distance.cosine(veriset_emb, query_word_embeddings_list[k])
            #cumle_list.append({dataset_tag : distances, 'sentence_id': df['SENTENCE_ID'][index]})
            cumle_list.append(distances)
   
    oldIndex = 1  
    results_list.append(result_list)
        

end_results_list = []

for i in range(0, len(results_list)):
    newlist = sorted(results_list[i], key=itemgetter('sentence_id'))
    end_results_list.append(newlist)


if not len(end_results_list) == 0:
    similarity_value_list = [0] * len(end_results_list[0])
    size = len(prediction)

    for i, list_dict in enumerate(end_results_list):
        for index, one_dict in enumerate(list_dict):   
            dict_values = list(one_dict.values())
            similarity_value_list[index] = similarity_value_list[index] + dict_values[1]

    similarity_value_list = [number / size for number in similarity_value_list]
    #print(similarity_value_list)


    results_dict = []
    for i, list_dict in enumerate(end_results_list):
        for index, one_dict in enumerate(list_dict):
            dict_values = list(one_dict.values())
            results_dict.append({'sentence_id': dict_values[0], 'distance': similarity_value_list[index]})
        break

    #print(results_dict)


    results_dict_2 = sorted(results_dict, key=lambda x: float(x['distance']), reverse=True)    
    result_100 = results_dict_2[:100]
    
    print(result_100)

    son = []
    for i, _dict in enumerate(result_100):
        for index, val in enumerate(all_sentences):
            if val['index'] == _dict['sentence_id']:
                son.append({'sentence' : val['sentence'], 'distance': _dict['distance']})

    for i, val in enumerate(son):
        print(i+1, val)
        print("\n")
else:
    print('!!! NO ENTITY !!! CANNOT COMPARE !!!')
# Out:
# 1 {'sentence': 'uyuşturucu veya uyarıcı madde verilen veya satılan kişinin çocuk olması halinde , veren veya satan kişiye verilecek hapis cezası on beş yıldan az olamaz .', 'distance': 0.8542696477600421}
#
#
# 2 {'sentence': 'istismarın sarkıntılık düzeyinde kalması halinde üç yıldan sekiz yıla kadar hapis cezasına hükmolunur .', 'distance': 0.848586386561252}
#
#
# 3 {'sentence': 'istismarın vücuda organ veya sair bir cisim sokulması suretiyle gerçekleştirilmesi durumunda , on altı yıldan aşağı olmamak üzere hapis cezasına hükmolunur .', 'distance': 0.848586386561252}
#
#
# 4 {'sentence': 'davranışın sarkıntılık düzeyinde kalması halinde iki yıldan beş yıla kadar hapis cezası verilir .', 'distance': 0.8480413823400923}
#
#
# 5 {'sentence': 'sırasında kamunun endişe ve heyecan duymasına neden olacak veya halkın maneviyatını sarsacak veya düşman karşısında ülkenin direncini azaltacak şekilde asılsız veya abartılmış veya özel maksada dayalı havadis veya haber yayan veya nakleden veya temel milli yararlara zarar verebilecek herhangi bir faaliyette bulunan kimseye beş yıldan on yıla kadar hapis cezası verilir .', 'distance': 0.8426663600501376}
#
#
# 6 {'sentence': 'cinsel yönden taciz şeklinde gerçekleşmesi halinde , on yıldan onbeş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8411174354770606}
#
#
# 7 {'sentence': 'güvenliğine veya iç veya dış siyasal yararlarına ilişkin belge veya vesikaları kısmen veya tamamen yok eden , tahrip eden veya bunlar üzerinde sahtecilik yapan veya geçici de olsa , bunları tahsis olundukları yerden başka bir yerde kullanan , hileyle alan veya çalan kimseye sekiz yıldan oniki yıla kadar hapis cezası verilir .', 'distance': 0.8244669792907168}
#
#
# 8 {'sentence': 've şiddet kullanarak Türkiye Cumhuriyeti Hükûmetini ortadan kaldırmaya veya görevlerini yapmasını kısmen veya tamamen engellemeye teşebbüs eden kimseye ağırlaştırılmış müebbet hapis cezası verilir .', 'distance': 0.8242796161875544}
#
#
# 9 {'sentence': 'yetkisi elinden alınmış olan ana veya babanın ya da üçüncü derece dahil kan hısmının , onaltı yaşını bitirmemiş bir çocuğu veli , vasi veya bakım ve gözetimi altında bulunan kimsenin yanından cebir veya tehdit kullanmaksızın kaçırması veya alıkoyması halinde , üç aydan bir yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8239871325470659}
#
#
# 10 {'sentence': 'askeri yararı gereği girilmesi yasaklanmış olan yerlere , gizlice veya hile ile girenlere iki yıldan beş yıla kadar hapis cezası verilir .', 'distance': 0.8210624745934482}
#
#
# 11 {'sentence': 'fiili işlemek için veya işlediği sırada cebir , tehdit veya hile kullanırsa , iki yıldan yedi yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8201069315729207}
#
#
# 12 {'sentence': 'yaralamanın vücutta kemik kırılmasına veya çıkığına neden olması halinde , yukarıdaki maddeye göre belirlenen ceza , kırık veya çıkığın hayat fonksiyonlarındaki etkisine göre , yarısına kadar artırılır .', 'distance': 0.8184712774216903}
#
#
# 13 {'sentence': 'yaralamanın ihmali davranışla işlenmesi halinde , verilecek ceza üçte ikisine kadar indirilebilir .', 'distance': 0.8184712774216903}
#
#
# 14 {'sentence': 'hizmetini yapanları firara sevk edecek veya askerlik hizmetine katılacak olanları bu hizmeti yapmaktan vazgeçirecek şekilde teşvik veya telkinde bulunanlara altı aydan iki yıla kadar hapis cezası verilir .', 'distance': 0.8181649432564576}
#
#
# 15 {'sentence': ';Silahla , Kişinin kendisini tanınmayacak bir hale koyması suretiyle , imzasız mektupla veya özel işaretlerle , Birden fazla kişi tarafından birlikte , Var olan veya var sayılan suç örgütlerinin oluşturdukları korkutucu güçten yararlanılarak , İşlenmesi halinde , fail hakkında iki yıldan beş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8151231928434339}
#
#
# 16 {'sentence': 'üyeliğinden dolayı verilecek ceza , yapılan yardımın niteliğine göre üçte birine kadar indirilebilir .', 'distance': 0.8150389699389663}
#
#
# 17 {'sentence': 'çekilmiş olan yabancı devlet bayrağını veya diğer egemenlik alametlerini alenen tahkir eden kimseye üç aydan bir yıla kadar hapis cezası verilir .', 'distance': 0.8132997353953941}
#
#
# 18 {'sentence': 'veya askeri idareye bağlı olarak görev yapan diğer kişileri kanunlara karşı itaatsizliğe veya yeminlerini bozmaya veya askeri disiplini veya askerlik hizmetine ilişkin görevlerini ihlale yönelten ve tahrik edenler ile kanunlara , yeminlere veya disiplin veya diğer görevlere aykırı hareketleri askerler önünde öven veya iyi gördüğünü söyleyen kimselere , bir yıldan üç yıla kadar hapis cezası verilir .', 'distance': 0.8118825040516011}
#
#
# 19 {'sentence': 'yazılı fiiller , savaş sırasında işlenmiş veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye koymuş ise müebbet hapis cezası verilir .', 'distance': 0.8107150371779187}
#
#
# 20 {'sentence': 'savaş sırasında işlenmiş veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye koymuşsa müebbet hapis cezası verilir .', 'distance': 0.8107150371779187}
#
#
# 21 {'sentence': 'Türkiye ile savaş halinde bulunan bir devletin yararına işlenir veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye sokacak olursa , faile müebbet hapis cezası verilir .', 'distance': 0.8107150371779187}
#
#
# 22 {'sentence': 'sonucu savaş meydana gelirse faile müebbet hapis cezası verilir .', 'distance': 0.8106672570686482}
#
#
# 23 {'sentence': 'güvenliği veya iç veya dış siyasal yararları bakımından , niteliği itibarıyla , gizli kalması gereken bilgileri , siyasal veya askeri casusluk maksadıyla temin eden kimseye onbeş yıldan yirmi yıla kadar hapis cezası verilir .', 'distance': 0.8098592456201708}
#
#
# 24 {'sentence': 'veya tehdit kullanarak , işçiyi veya işverenlerini ücretleri azaltıp çoğaltmaya veya evvelce kabul edilenlerden başka koşullar altında anlaşmalar kabulüne zorlayan ya da bir işin durmasına , sona ermesine veya durmanın devamına neden olan kişiye altı aydan üç yıla kadar hapis cezası verilir .', 'distance': 0.8088132207502049}
#
#
# 25 {'sentence': 'Devletini savaş tehlikesi ile karşı karşıya bırakacak şekilde , yetkisiz olarak , yabancı bir devlete karşı asker toplayan veya diğer hasmane hareketlerde bulunan kimseye beş yıldan oniki yıla kadar hapis cezası verilir .', 'distance': 0.8085287410130789}
#
#
# 26 {'sentence': 'savaş zamanında işlenmiş veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye koymuşsa , faile on yıldan onbeş yıla kadar hapis cezası verilir .', 'distance': 0.8085287410130789}
#
#
# 27 {'sentence': 'Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeyle karşı karşıya bırakmış ise faile beş yıldan on yıla kadar hapis cezası verilir .', 'distance': 0.8085287410130789}
#
#
# 28 {'sentence': 'savaş zamanında işlenmiş veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye sokmuş ise faile on yıldan onbeş yıla kadar hapis cezası verilir .', 'distance': 0.8085287410130789}
#
#
# 29 {'sentence': 'savaş zamanında işlenirse faile üç yıldan sekiz yıla kadar hapis cezası verilir .', 'distance': 0.8085287410130789}
#
#
# 30 {'sentence': 'ile savaş halinde bulunan bir devletten akademik derece veya şeref , unvan , nişan ve diğer fahri rütbe veya bunlara ait maaş veya başka yararlar kabul eden vatandaşa bir yıldan üç yıla kadar hapis cezası verilir .', 'distance': 0.8085225034043287}
#
#
#
#
# 42 {'sentence': 'veya tehdit kullanılarak ya da hukuka aykırı başka bir davranışla ; Bir kamu faaliyetinin yürütülmesine , Kamu kurumlarında veya kamu kurumu niteliğindeki meslek kuruluşlarında verilen ya da kamu makamlarının verdiği izne dayalı olarak sunulan hizmetlerden yararlanılmasına , engel olunması halinde , fail hakkında iki yıldan beş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8053584385900971}
#
#
# 43 {'sentence': 'veya tehdit kullanılarak ya da hukuka aykırı başka bir davranışla bir siyasi partinin faaliyetlerinin engellenmesi halinde , iki yıldan beş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8053584385900971}
#
#
# 44 {'sentence': 'veya tehdit kullanılarak ya da hukuka aykırı başka bir davranışla bir sendikanın faaliyetlerinin engellenmesi halinde , bir yıldan üç yıla kadar hapis cezasına hükmolunur .', 'distance': 0.8053584385900971}
#
#
# 45 {'sentence': 've şiddet kullanarak Türkiye Büyük Millet Meclisini ortadan kaldırmaya veya Türkiye Büyük Millet Meclisinin görevlerini kısmen veya tamamen yapmasını engellemeye teşebbüs edenler ağırlaştırılmış müebbet hapis cezasıyla cezalandırılırlar .', 'distance': 0.8049148053180614}
#
#
# 46 {'sentence': 've ikinci fıkrada tanımlanan suçların , Devletin savaş halinde olmasının sağladığı kolaylıktan yararlanmak suretiyle işlenmesi halinde , ağırlaştırılmış müebbet hapis cezasına hükmolunur .', 'distance': 0.8037234194770503}
#
#
# 47 {'sentence': ';Türkiye ile savaş halinde bulunan bir devletin çıkarı için işlenmiş olması , Devletin savaş hazırlıklarını veya savaş kudret ve yeteneğini veya askeri hareketlerini tehlikeye koymuş olması , Halinde , ağırlaştırılmış müebbet hapis cezasına hükmolunur .', 'distance': 0.8037227636672606}
#
#
# 48 {'sentence': 'on iki yaşını tamamlamamış olması halinde verilecek ceza , istismar durumunda on yıldan , sarkıntılık durumunda beş yıldan az olamaz .', 'distance': 0.8036447753454592}
#
#
# 49 {'sentence': 'fıkrada tanımlanan fiilin taksirle işlenmesi halinde , iki yıldan beş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.801996902002808}
#
#
# 50 {'sentence': 'tehdit ve hile olmaksızın , onbeş yaşını bitirmiş olan çocukla cinsel ilişkide bulunan kişi , şikayet üzerine , iki yıldan beş yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.8016195978776501}
#
#
# 51 {'sentence': 'kamu görevini , kanun ve nizamlara aykırı olarak yerine getirmeye teşebbüs eden veya terk emri kendisine bildirilmiş olduğu halde görevi sürdüren kimseye üç aydan iki yıla kadar hapis cezası verilir .', 'distance': 0.800436286316241}
#
#
# 52 {'sentence': 'maddede tanımlanan suçların işleneceğini haber alıp da bunları zamanında yetkililere ihbar etmeyenlere , suç teşebbüs derecesinde kalmış olsa bile altı aydan iki yıla kadar hapis cezası verilir .', 'distance': 0.800436286316241}
#
#
# 53 {'sentence': 'cebir , şiddet veya tehdit içeren yöntemlerini meşru gösterecek veya övecek ya da bu yöntemlere başvurmayı teşvik edecek şekilde propagandasını yapan kişi , bir yıldan üç yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0
ıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7919582638516743}
#
#
# 72 {'sentence': 've altsoy ilişkisinden doğan nüfuz kullanılmak suretiyle suça azmettirme halinde , azmettirenin cezası üçte birden yarısına kadar artırılır .', 'distance': 0.7914103501876385}
#
#
# 73 {'sentence': 'Cumhuriyeti Devleti ile savaş halinde olan devletin ordusunda hizmet kabul eden , düşman devletin yanında Türkiye Cumhuriyeti Devletine karşı silahlı mücadeleye giren vatandaş , müebbet hapis cezası ile cezalandırılır .', 'distance': 0.7904246013338986}
#
#
# 74 {'sentence': 'cebir veya tehdit kullanılmak suretiyle ya da gece vakti işlenmesi halinde , bir yıldan üç yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7885019081046605}
#
#
# 75 {'sentence': 'suçunun ; Silahla , Kişinin kendisini tanınmayacak bir hale koyması suretiyle , Birden fazla kişi tarafından birlikte , Yol kesmek suretiyle ya da konutta , işyerinde veya bunların eklentilerinde , Beden veya ruh bakımından kendisini savunamayacak durumda bulunan kişiye karşı , Var olan veya var sayılan suç örgütlerinin oluşturdukları korkutucu güçten yararlanılarak , Suç örgütüne yarar sağlamak maksadıyla , Gece vaktinde , İşlenmesi halinde , fail hakkında on yıldan onbeş yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7884771092161521}
#
#
# 76 {'sentence': 'suçun , cebir veya tehdit kullanılarak işlenmesi halinde , bir yıldan üç yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7884466320132041}
#
#
# 77 {'sentence': 'zamanında yükümlülüklerin yerine getirilmesinde hile yapan yukarıdaki fıkralarda yazılı kişilere on yıldan onbeş yıla kadar hapis ve onbin güne kadar adli para cezası verilir .', 'distance': 0.7876849961713651}
#
#
# 78 {'sentence': 'Türkiye Cumhuriyeti Hükûmetine karşı silahlı bir isyana tahrik eden kimseye onbeş yıldan yirmi yıla kadar hapis cezası verilir .', 'distance': 0.7874798818508676}
#
#
# 79 {'sentence': "veya uyarıcı madde ihracı fiilinin diğer ülke açısından ithal olarak nitelendirilmesi dolayısıyla bu ülkede yapılan yargılama sonucunda hükmolunan cezanın infaz edilen kısmı , Türkiye'de uyuşturucu veya uyarıcı madde ihracı dolayısıyla yapılacak yargılama sonucunda hükmolunan cezadan mahsup edilir .", 'distance': 0.7874653453007477}
#
#
# 80 {'sentence': 'Cumhuriyeti Hükûmetine karşı silahlı isyanı idare eden kişi , ağırlaştırılmış müebbet hapis cezası ile cezalandırılır .', 'distance': 0.7857478306186936}
#
#
# 81 {'sentence': 'kimseye karşı ; Bir siyasi partiye üye olmaya veya olmamaya , siyasi partinin faaliyetlerine katılmaya veya katılmamaya , siyasi partiden veya siyasi parti yönetimindeki görevinden ayrılmaya , Seçim yoluyla gelinen bir kamu görevine aday olmamaya veya seçildiği görevden ayrılmaya , ‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚Äì‚ÄìZorlamak amacıyla , cebir veya tehdit kullanan kişi , bir yıldan üç yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7854792849561676}
#
#
# 82 {'sentence': 'kimseye karşı bir sendikaya üye olmaya veya olmamaya , sendikanın faaliyetlerine katılmaya veya katılmamaya , sendikadan veya sendika yönetimindeki görevinden ayrılmaya zorlamak amacıyla , cebir veya tehdit kullanan kişi , altı aydan iki yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7854619702544849}
#
#
# 83 {'sentence': 'sahanlığında veya münhasır ekonomik bölgede kurulmuş sabit bir platformu cebir veya tehdit kullanarak ya da hukuka aykırı başka bir davranışla ele geçiren , zapteden veya kontrolü altına alan kişi , beş yıldan onbeş yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7854619702544849}
#
#
# 84 {'sentence': ';Türkiye ile savaş halinde bulunan bir devletin yararına işlenmişse , Savaş sırasında işlenmiş veya Devletin savaş hazırlıklarını veya savaş etkinliğini veya askeri hareketlerini tehlikeye sokmuşsa , Fail , ağırlaştırılmış müebbet hapis cezası ile cezalandırılır .', 'distance': 0.784891149324879}
#
#
# 85 {'sentence': 'istismarın , birinci fıkranın bendindeki çocuklara karşı cebir veya tehditle ya da bendindeki çocuklara karşı silah kullanmak suretiyle gerçekleştirilmesi halinde , yukarıdaki fıkralara göre verilecek ceza yarı oranında artırılır .', 'distance': 0.7838801194873861}
#
#
# 86 {'sentence': 'Onsekiz yaşını doldurmamış olanların birinci fıkrada belirtilen maksatlarla tedarik edilmeleri , kaçırılmaları , bir yerden diğer bir yere götürülmeleri veya sevk edilmeleri veya barındırılmaları hallerinde suça ait araç fiillerden hiçbirine başvurulmuş olmasa da faile birinci fıkrada belirtilen cezalar verilir .', 'distance': 0.7834132675332689}
#
#
# 87 {'sentence': 'alınan , tutuklu veya hükümlünün , muhafaza veya nakli ile görevli kişinin dikkat ve özen yükümlülüğüne aykırı davranmasından yararlanarak kaçması halinde , altı aydan üç yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7826347761310233}
#
#
# 88 {'sentence': 'veya tehdit kullanarak , bir kimseyi dini , siyasi , sosyal , felsefi inanç , düşünce ve kanaatlerini açıklamaya veya değiştirmeye zorlayan ya da bunları açıklamaktan , yaymaktan meneden kişi , bir yıldan üç yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7824707569781085}
#
#
# 89 {'sentence': 'veya tehdit kullanarak ya da hukuka aykırı başka bir davranışla kara ulaşım aracının hareket etmesini engelleyen , bu aracı hareket halinde iken durduran veya gitmekte olduğu yerden başka yere götüren kişi , bir yıldan üç yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7824707569781085}
#
#
# 90 {'sentence': 'veya tehdit kullanarak ya da hukuka aykırı başka bir davranışla hava ulaşım aracının hareket etmesini engelleyen veya bu aracı gitmekte olduğu yerden başka yere götüren kişi , beş yıldan on yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7824707569781085}
#
#
# 91 {'sentence': 'Türkiye Cumhuriyeti Devletine karşı savaş açması veya hasmane hareketlerde bulunması için yabancı devlet yetkililerini tahrik eden veya bu amaca yönelik olarak yabancı devlet yetkilileri ile işbirliği yapan kişi , on yıldan yirmi yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7821862772409826}
#
#
# 92 {'sentence': 'başkasını , kendisinin veya yakınının hayatına , vücut veya cinsel dokunulmazlığına yönelik bir saldırı gerçekleştireceğinden ya da malvarlığı itibarıyla büyük bir zarara uğratacağından bahisle tehdit ederek veya cebir kullanarak , bir malı teslime veya malın alınmasına karşı koymamaya mecbur kılan kişi , altı yıldan on yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7810262924400632}
#
#
# 93 {'sentence': 'fıkrada yazılı fiil kadının beden veya ruh sağlığı bakımından bir zarara uğramasına neden olmuşsa , kişi altı yıldan oniki yıla kadar hapis cezası ile cezalandırılır ; fiilin kadının ölümüne neden olması halinde , onbeş yıldan yirmi yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7791612248780119}
#
#
# 94 {'sentence': 'fıkrada yazılı fiil kadının beden veya ruh sağlığı bakımından bir zarara uğramasına neden olmuşsa , kişi üç yıldan altı yıla kadar hapis cezası ile cezalandırılır ; fiilin kadının ölümüne neden olması halinde , dört yıldan sekiz yıla kadar hapis cezasına hükmolunur .', 'distance': 0.7791612248780119}
#
#
# 95 {'sentence': 'veya hayvanlar açısından tedavisi zor hastalıkların ortaya çıkmasına , üreme yeteneğinin körelmesine , hayvanların veya bitkilerin doğal özelliklerini değiştirmeye neden olabilecek niteliklere sahip olan atık veya artıkların toprağa , suya veya havaya taksirle verilmesine neden olan kişi , bir yıldan beş yıla kadar hapis cezası ile cezalandırılır .', 'distance': 0.7791265350925022}
#
#
# 96 {'sentence': 'yaralama fiilinin kişi üzerindeki etkisinin basit bir tıbbi müdahaleyle giderilebilecek ölçüde hafif olması halinde , mağdurun şikayeti üzerine , dört aydan bir yıla kadar hapis veya adli para cezasına hükmolunur .', 'distance': 0.7764856249355759}
#
#
# 97 {'sentence': 'oynanması için yer ve imkan sağlayan kişi , bir yıldan üç yıla kadar hapis ve iki yüz günden aşağı olmamak üzere adli para cezası ile cezalandırılır .', 'distance': 0.7751608089396592}
#
#
# 98 {'sentence': 'bir meslek veya sanatın ya da trafik düzeninin gerektirdiği dikkat ve özen yükümlülüğüne aykırılık dolayısıyla işlenen taksirli suçtan mahkûmiyet halinde , üç aydan az ve üç yıldan fazla olmamak üzere , bu meslek veya sanatın icrasının yasaklanmasına ya da sürücü belgesinin geri alınmasına karar verilebilir .', 'distance': 0.7746325594344077}
#
#
# 99 {'sentence': 've öğretimin engellenmesi , kamu kurumu veya kamu kurumu niteliğindeki meslek kuruluşlarının faaliyetlerinin engellenmesi , siyasi hakların kullanılmasının engellenmesi , inanç , düşünce ve kanaat hürriyetinin kullanılmasını engelleme , konut dokunulmazlığının ihlali ile iş ve çalışma hürriyetinin ihlali suçlarının ; Silahla , Kişinin kendisini tanınmayacak bir hale koyması suretiyle , imzasız mektupla veya özel işaretlerle , Birden fazla kişi tarafından birlikte , Var olan veya var sayılan suç örgütlerinin oluşturdukları korkutucu güçten yararlanılarak , Kamu görevinin sağladığı nüfuz kötüye kullanılmak suretiyle , İşlenmesi halinde , verilecek ceza bir kat artırılır .', 'distance': 0.7742970725840502}
#
#
# 100 {'sentence': 'silahla ya da var olan veya var sayılan suç örgütlerinin oluşturdukları korkutucu güçten yararlanılarak işlenmesi halinde , yukarıdaki fıkralara göre verilecek ceza yarı oranında artırılır .', 'distance': 0.7742970725840502}

# %%
### SBERT ###

# Install BERT model by using SentenceTransformer package.
model = SentenceTransformer('dbmdz/bert-base-turkish-128k-cased')

# %%
sentences = input_df['SENTENCE'].values.tolist()

sentence_embeddings = model.encode(sentences)

print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))

print('Sample BERT embedding vector - note includes negative values', sentence_embeddings[0])
